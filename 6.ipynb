# %% [markdown]
# # Read CSV file in pandas

# %%
import pandas as pd 

csv_1 = pd.read_csv('/home/crazyguy/VS Code/ML Tutorial/machine_learning/vgsales.csv')
csv_1
# Out:
#         Rank                                               Name Platform  \
# 0        259                                          Asteroids     2600
# 1        545                                    Missile Command     2600
# 2       1768                                            Kaboom!     2600
# 3       1971                                           Defender     2600
# 4       2671                                             Boxing     2600
# ...      ...                                                ...      ...
# 16319  16565                                       Mighty No. 9     XOne
# 16320  16572                                 Resident Evil 4 HD     XOne
# 16321  16573                      Farming 2017 - The Simulation      PS4
# 16322  16579                                  Rugby Challenge 3     XOne
# 16323  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
#        Year       Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# csv_2 = pd.read_csv('/home/crazyguy/VS Code/ML Tutorial/machine_learning/vgsales.csv',usecols=["Rank","Name"])
csv_2 = pd.read_csv('/home/crazyguy/VS Code/ML Tutorial/machine_learning/vgsales.csv',usecols=[0,3])
csv_2
# Out:
#         Rank  Year
# 0        259  1980
# 1        545  1980
# 2       1768  1980
# 3       1971  1980
# 4       2671  1980
# ...      ...   ...
# 16319  16565  2016
# 16320  16572  2016
# 16321  16573  2016
# 16322  16579  2016
# 16323  16592  2016
#
# [16324 rows x 2 columns]

# %%
csv_3 = pd.read_csv('/home/crazyguy/VS Code/ML Tutorial/machine_learning/vgsales.csv',skiprows=[0,3])
csv_3
# Out:
#          259                                          Asteroids  2600  1980  \
# 0        545                                    Missile Command  2600  1980
# 1       1971                                           Defender  2600  1980
# 2       2671                                             Boxing  2600  1980
# 3       4027                                         Ice Hockey  2600  1980
# 4       5368                                            Freeway  2600  1980
# ...      ...                                                ...   ...   ...
# 16317  16565                                       Mighty No. 9  XOne  2016
# 16318  16572                                 Resident Evil 4 HD  XOne  2016
# 16319  16573                      Farming 2017 - The Simulation   PS4  2016
# 16320  16579                                  Rugby Challenge 3  XOne  2016
# 16321  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...   PSV  2016
#
# ...

# %%
csv_4 = pd.read_csv('/home/crazyguy/VS Code/ML Tutorial/machine_learning/vgsales.csv',index_col="Rank")
csv_4
# Out:
#                                                     Name Platform  Year  \
# Rank
# 259                                            Asteroids     2600  1980
# 545                                      Missile Command     2600  1980
# 1768                                             Kaboom!     2600  1980
# 1971                                            Defender     2600  1980
# 2671                                              Boxing     2600  1980
# ...                                                  ...      ...   ...
# 16565                                       Mighty No. 9     XOne  2016
# 16572                                 Resident Evil 4 HD     XOne  2016
# 16573                      Farming 2017 - The Simulation      PS4  2016
# 16579                                  Rugby Challenge 3     XOne  2016
# 16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV  2016
#
#             Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Rank
# ...

# %%
csv_5 = pd.read_csv('/home/crazyguy/VS Code/ML Tutorial/machine_learning/vgsales.csv',header=1)
csv_5
# Out:
#          259                                          Asteroids  2600  1980  \
# 0        545                                    Missile Command  2600  1980
# 1       1768                                            Kaboom!  2600  1980
# 2       1971                                           Defender  2600  1980
# 3       2671                                             Boxing  2600  1980
# 4       4027                                         Ice Hockey  2600  1980
# ...      ...                                                ...   ...   ...
# 16318  16565                                       Mighty No. 9  XOne  2016
# 16319  16572                                 Resident Evil 4 HD  XOne  2016
# 16320  16573                      Farming 2017 - The Simulation   PS4  2016
# 16321  16579                                  Rugby Challenge 3  XOne  2016
# 16322  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...   PSV  2016
#
# ...

# %%
csv_6 = pd.read_csv('/home/crazyguy/VS Code/ML Tutorial/machine_learning/vgsales.csv',names=["col1","col2","col3","col4","col5",])
csv_6
# Out:
#                                                                                                             col1  \
# Rank  Name                                               Platform Year Genre      Publisher             NA_Sales
# 259   Asteroids                                          2600     1980 Shooter    Atari                        4
# 545   Missile Command                                    2600     1980 Shooter    Atari                     2.56
# 1768  Kaboom!                                            2600     1980 Misc       Activision                1.07
# 1971  Defender                                           2600     1980 Misc       Atari                     0.99
# ...                                                                                                          ...
# 16565 Mighty No. 9                                       XOne     2016 Platform   Deep Silver               0.01
# ...

# %%
csv_7 = pd.read_csv('/home/crazyguy/VS Code/ML Tutorial/machine_learning/vgsales.csv',header=None)
csv_7
# Out:
#           0                                                  1         2   \
# 0       Rank                                               Name  Platform
# 1        259                                          Asteroids      2600
# 2        545                                    Missile Command      2600
# 3       1768                                            Kaboom!      2600
# 4       1971                                           Defender      2600
# ...      ...                                                ...       ...
# 16320  16565                                       Mighty No. 9      XOne
# 16321  16572                                 Resident Evil 4 HD      XOne
# 16322  16573                      Farming 2017 - The Simulation       PS4
# 16323  16579                                  Rugby Challenge 3      XOne
# 16324  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...       PSV
#
#          3           4                     5         6         7         8   \
# ...

# %%
csv_8 = pd.read_csv('/home/crazyguy/VS Code/ML Tutorial/machine_learning/vgsales.csv',dtype = {"TODAY - VOLUME":"float"})
csv_8
# Out:
#         Rank                                               Name Platform  \
# 0        259                                          Asteroids     2600
# 1        545                                    Missile Command     2600
# 2       1768                                            Kaboom!     2600
# 3       1971                                           Defender     2600
# 4       2671                                             Boxing     2600
# ...      ...                                                ...      ...
# 16319  16565                                       Mighty No. 9     XOne
# 16320  16572                                 Resident Evil 4 HD     XOne
# 16321  16573                      Farming 2017 - The Simulation      PS4
# 16322  16579                                  Rugby Challenge 3     XOne
# 16323  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
#        Year       Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...
