# %% [markdown]
# # **Pandas Function Python CSV file reading and writing**

# %%
import pandas as pd 
csv1 = pd.read_csv("/home/crazyguy/VS Code/ML Tutorial/machine_learning/vgsales.csv")
csv1
# Out:
#         Rank                                               Name Platform  \
# 0        259                                          Asteroids     2600
# 1        545                                    Missile Command     2600
# 2       1768                                            Kaboom!     2600
# 3       1971                                           Defender     2600
# 4       2671                                             Boxing     2600
# ...      ...                                                ...      ...
# 16319  16565                                       Mighty No. 9     XOne
# 16320  16572                                 Resident Evil 4 HD     XOne
# 16321  16573                      Farming 2017 - The Simulation      PS4
# 16322  16579                                  Rugby Challenge 3     XOne
# 16323  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
#        Year       Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
csv1.index
# Out:
# RangeIndex(start=0, stop=16324, step=1)

# %%
csv1.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
csv1.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16324.000000  16324.000000  16324.000000  16324.000000  16324.000000
# mean    8291.508270   2006.404251      0.265464      0.147581      0.078673
# std     4792.043734      5.826744      0.821658      0.508809      0.311584
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4135.750000   2003.000000      0.000000      0.000000      0.000000
# 50%     8293.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12439.250000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2016.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16324.000000  16324.000000
# mean       0.048334      0.540328
# std        0.189902      1.565860
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.480000
# ...

# %%
csv1.head(2)
# Out:
#    Rank             Name Platform  Year    Genre Publisher  NA_Sales  \
# 0   259        Asteroids     2600  1980  Shooter     Atari      4.00
# 1   545  Missile Command     2600  1980  Shooter     Atari      2.56
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      0.26       0.0         0.05          4.31
# 1      0.17       0.0         0.03          2.76

# %%
csv1.tail(2)
# Out:
#         Rank                                               Name Platform  \
# 16322  16579                                  Rugby Challenge 3     XOne
# 16323  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
#        Year   Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16322  2016  Sports  Alternative Software       0.0      0.01      0.00
# 16323  2016  Action       dramatic create       0.0      0.00      0.01
#
#        Other_Sales  Global_Sales
# 16322          0.0          0.01
# 16323          0.0          0.01

# %%
csv1[6:11]
# Out:
#     Rank      Name Platform  Year     Genre     Publisher  NA_Sales  EU_Sales  \
# 6   5368   Freeway     2600  1980    Action    Activision      0.32      0.02
# 7   6319    Bridge     2600  1980      Misc    Activision      0.25      0.02
# 8   6898  Checkers     2600  1980      Misc         Atari      0.22      0.01
# 9    240  Pitfall!     2600  1981  Platform    Activision      4.21      0.24
# 10   736   Frogger     2600  1981    Action  Parker Bros.      2.06      0.12
#
#     JP_Sales  Other_Sales  Global_Sales
# 6        0.0         0.00          0.34
# 7        0.0         0.00          0.27
# 8        0.0         0.00          0.24
# 9        0.0         0.05          4.50
# 10       0.0         0.02          2.20

# %%
print(type(csv1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
csv1.index.array
# Out:
# <NumpyExtensionArray>
# [    np.int64(0),     np.int64(1),     np.int64(2),     np.int64(3),
#      np.int64(4),     np.int64(5),     np.int64(6),     np.int64(7),
#      np.int64(8),     np.int64(9),
#  ...
#  np.int64(16314), np.int64(16315), np.int64(16316), np.int64(16317),
#  np.int64(16318), np.int64(16319), np.int64(16320), np.int64(16321),
#  np.int64(16322), np.int64(16323)]
# Length: 16324, dtype: int64

# %%
csv1.to_numpy()
# Out:
# array([[259, 'Asteroids', '2600', ..., 0.0, 0.05, 4.31],
#        [545, 'Missile Command', '2600', ..., 0.0, 0.03, 2.76],
#        [1768, 'Kaboom!', '2600', ..., 0.0, 0.01, 1.15],
#        ...,
#        [16573, 'Farming 2017 - The Simulation', 'PS4', ..., 0.0, 0.0,
#         0.01],
#        [16579, 'Rugby Challenge 3', 'XOne', ..., 0.0, 0.0, 0.01],
#        [16592, 'Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirube Kareru',
#         'PSV', ..., 0.01, 0.0, 0.01]], shape=(16324, 11), dtype=object)

# %%
# import numpy as np 
# v = np.asarray(csv1)
# v

# %%
csv1.sort_index(axis=0,ascending=False)
# Out:
#         Rank                                               Name Platform  \
# 16323  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16322  16579                                  Rugby Challenge 3     XOne
# 16321  16573                      Farming 2017 - The Simulation      PS4
# 16320  16572                                 Resident Evil 4 HD     XOne
# 16319  16565                                       Mighty No. 9     XOne
# ...      ...                                                ...      ...
# 4       2671                                             Boxing     2600
# 3       1971                                           Defender     2600
# 2       1768                                            Kaboom!     2600
# 1        545                                    Missile Command     2600
# 0        259                                          Asteroids     2600
#
#        Year       Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# csv1.loc[0,"Rank"]="Python"
# csv1

# %%
csv1.loc[[1,2],:]
# Out:
#    Rank             Name Platform  Year    Genre   Publisher  NA_Sales  \
# 1   545  Missile Command     2600  1980  Shooter       Atari      2.56
# 2  1768          Kaboom!     2600  1980     Misc  Activision      1.07
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 1      0.17       0.0         0.03          2.76
# 2      0.07       0.0         0.01          1.15

# %%
csv1.iloc[0,2]
# Out:
# '2600'

# %%
csv1.drop(0,axis=0)
# Out:
#         Rank                                               Name Platform  \
# 1        545                                    Missile Command     2600
# 2       1768                                            Kaboom!     2600
# 3       1971                                           Defender     2600
# 4       2671                                             Boxing     2600
# 5       4027                                         Ice Hockey     2600
# ...      ...                                                ...      ...
# 16319  16565                                       Mighty No. 9     XOne
# 16320  16572                                 Resident Evil 4 HD     XOne
# 16321  16573                      Farming 2017 - The Simulation      PS4
# 16322  16579                                  Rugby Challenge 3     XOne
# 16323  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
#        Year       Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...
